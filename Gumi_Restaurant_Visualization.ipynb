# %%
import folium
import pickle
import pandas as pd
import pickle
from urllib import parse
import requests
import json
import branca.colormap as cm

pd.set_option('display.max_rows', None)

# %%
with open('restaurant_total_score.pickle', 'rb') as f:
    total_score = pickle.load(f)

# %%
total_score
# Out:
#             식당이름  방문횟수     사용금액   인원   인당가격   평점  리뷰개수  \
# 0          한데만데이    36  5206000  326  15969  4.2   125
# 1        금오산해물탕찜    27  6331000  350  53621  4.0   371
# 2           거제복집    28  3260000  230  14173  4.0   123
# 3          오리하우스    27  4210000  357  11792  4.2    46
# 4           다미초밥    27  3547000  213  16652  4.5    22
# 5         포항가자미회    23  3287000  201  16353  4.1    89
# 6         논두렁밭두렁    25  3052000  266  11473  4.8    10
# 7           이조곰탕    22  2833000  163  17380  4.1    60
# 8            취팔선    16  3263500  189  17267  3.8   415
# 9         팔공식육식당    21  6635000  264  25132  3.4    11
# 10           산노을    17  3263000  181  18027  3.8    50
# 11           큰마당    18  2291000  144  15909  3.0     9
# 12            세정    16   825000   85   9705  4.0    33
# 13         정마담식당    13  1910000  146  22567  3.8   181
# 14      고향복어샤브샤브    15  2120000  154  13766  3.6    37
# 15   구미칠곡축협한우프라자     7  1588000   92  17260  4.1   498
# ...

# %%
#지도 그래프를 그리려고 하는데 total_score 위치값에 formatted_address가 아닌, 
#google_pluscode 또는 전화번호기 적힌 경우가 있어 직접 값을 변경해줌
#잘못 가져온 값이 상당히 많다

total_score.loc[18, '위치'] = '경상북도 구미시 산동면 인덕리 12'
total_score.loc[27, '위치'] = '경상북도 구미시 고아읍 원호리 491-8'
total_score.loc[35, '위치'] = '경상북도 구미시 고아읍 선산대로 1086-5'
total_score.loc[68, '위치'] = '경상북도 구미시 신평동 129-15'
total_score.loc[92, '위치'] = '경상북도 구미시 도량동 608-22'
total_score.loc[103, '위치'] = '경상북도 구미시 봉곡동 380-1'
total_score.loc[106, '위치'] = '경상북도 구미시 산동면 인덕리 618-2'
total_score.loc[116, '위치'] = '경상북도 구미시 봉곡동 402-1'
total_score.loc[129, '위치'] = '경상북도 구미시 산동면 적림리 524-7'
total_score.loc[132, '위치'] = '경상북도 구미시 양포동 152'
total_score.loc[134, '위치'] = '경상북도 구미시 남통동 290-6'
total_score.loc[136, '위치'] = '경상북도 구미시 형곡동 256-5'
total_score.loc[138, '위치'] = '경상북도 구미시 도개면 도군로 123'
total_score.loc[140, '위치'] = '경상북도 구미시 상모동 532-5'

# %%
total_score
# Out:
#             식당이름  방문횟수     사용금액   인원   인당가격   평점  리뷰개수  \
# 0          한데만데이    36  5206000  326  15969  4.2   125
# 1        금오산해물탕찜    27  6331000  350  53621  4.0   371
# 2           거제복집    28  3260000  230  14173  4.0   123
# 3          오리하우스    27  4210000  357  11792  4.2    46
# 4           다미초밥    27  3547000  213  16652  4.5    22
# 5         포항가자미회    23  3287000  201  16353  4.1    89
# 6         논두렁밭두렁    25  3052000  266  11473  4.8    10
# 7           이조곰탕    22  2833000  163  17380  4.1    60
# 8            취팔선    16  3263500  189  17267  3.8   415
# 9         팔공식육식당    21  6635000  264  25132  3.4    11
# 10           산노을    17  3263000  181  18027  3.8    50
# 11           큰마당    18  2291000  144  15909  3.0     9
# 12            세정    16   825000   85   9705  4.0    33
# 13         정마담식당    13  1910000  146  22567  3.8   181
# 14      고향복어샤브샤브    15  2120000  154  13766  3.6    37
# 15   구미칠곡축협한우프라자     7  1588000   92  17260  4.1   498
# ...

# %%
#folium에서 formatted_address를 입력하니 위치 결과가 반환되지 않아서 google geocoding api를 이용해 위도 경도로 바꾸어주었다.

my_api_key = 'AIzaSyDVwZKPyzz9-NOHUdGWp1tgTZTsBffon-o'
geocoding_url = 'https://maps.googleapis.com/maps/api/geocode/json?key={key}&language=ko&'

geometry_address = {}

for ind,row in total_score.iterrows():
    input_address = parse.urlencode({"address" : row['위치']}, encoding='utf-8')
    search_url = geocoding_url.format(key = my_api_key) + input_address
    data = requests.get(search_url).json()
    
    if(data['status'] == 'OK'):
        lat = data['results'][0]['geometry']['location']['lat']
        lng = data['results'][0]['geometry']['location']['lng']
        geometry_address[row['식당이름']] = [lat,lng]

# %%
total_score["위도_경도"] = total_score['식당이름'].map(geometry_address)

total_score
# Out:
#             식당이름  방문횟수     사용금액   인원   인당가격   평점  리뷰개수  \
# 0          한데만데이    36  5206000  326  15969  4.2   125
# 1        금오산해물탕찜    27  6331000  350  53621  4.0   371
# 2           거제복집    28  3260000  230  14173  4.0   123
# 3          오리하우스    27  4210000  357  11792  4.2    46
# 4           다미초밥    27  3547000  213  16652  4.5    22
# 5         포항가자미회    23  3287000  201  16353  4.1    89
# 6         논두렁밭두렁    25  3052000  266  11473  4.8    10
# 7           이조곰탕    22  2833000  163  17380  4.1    60
# 8            취팔선    16  3263500  189  17267  3.8   415
# 9         팔공식육식당    21  6635000  264  25132  3.4    11
# 10           산노을    17  3263000  181  18027  3.8    50
# 11           큰마당    18  2291000  144  15909  3.0     9
# 12            세정    16   825000   85   9705  4.0    33
# 13         정마담식당    13  1910000  146  22567  3.8   181
# 14      고향복어샤브샤브    15  2120000  154  13766  3.6    37
# 15   구미칠곡축협한우프라자     7  1588000   92  17260  4.1   498
# ...

# %%
center = [36.119626, 128.344300]

m = folium.Map(location = center, zoom_start=13)

# %%
colormap = cm.linear.YlOrRd_09.scale(0, 100)
colormap = colormap.to_step(index=[0, 20, 40, 60, 80, 100])
colormap.caption = 'Gumi Best Restaurant Top 100 '
colormap.add_to(m)
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ffffccff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %%
for ind, row in total_score[:100].iterrows():
    
    summary = f"<b>방문횟수 : </b>{row['방문횟수']}회<br><b>구글평점 : </b>{row['평점']}점<br><b>리뷰개수 : </b>{row['리뷰개수']}개<br><b>인당가격 : </b>{row['인당가격']}원"
    iframe = folium.IFrame(summary,width=200,height=100)
    popup = folium.Popup(iframe, max_width=200)
    
    folium.CircleMarker(
    location = row['위도_경도'], 
    tooltip = f"{ind}위, {row['식당이름']}",
    popup = popup,
    radius=5,
    color = f'{colormap.rgba_hex_str(ind)}',
    fill_color = f'{colormap.rgba_hex_str(ind)}',
    fill_opacity = 0.7,
    fill=True
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('Gumi_Best_Restaurant_Top_100.html')
